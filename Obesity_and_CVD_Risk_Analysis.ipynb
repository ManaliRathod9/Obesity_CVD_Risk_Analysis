# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %% [markdown]
# ### A). Summarize the data. How much data is present? What attributes/features are continuous valued? Which attributes are categorical?

# %%
# Load the dataset - ObesityDataSet.csv
data = pd.read_csv("https://raw.githubusercontent.com/ManaliRathod9/top_universities_ranking_2024/refs/heads/main/ObesityDataSet.csv")

# %%
print("Displayed below are the first 5 rows of the dataset : -")
print()
data.head()
# Out:
# Displayed below are the first 5 rows of the dataset : -
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# ...

# %%
# Calculate the lenght of dataset
print("The length of the record is: ",len(data))
# Out:
# The length of the record is:  2111

# %%
# Calculate the number of records and attributes
print(f"Total  records: -  {data.shape[0]}")
print(f"Total nattributes/features: - {data.shape[1]}")
# Out:
# Total  records: -  2111
# Total nattributes/features: - 17

# %%
print("Overview of Data Types and Missing Values\n")
data.info()
# Out:
# Overview of Data Types and Missing Values
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
# ...

# %%
# Identify continuous columns (float & int)
continuous_columns = data.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Identify categorical columns (object)
categorical_columns = data.select_dtypes(include=['object']).columns.tolist()

print(f"Continuous Valued Attributes: {continuous_columns}")
print()
print(f"Categorical Attributes: {categorical_columns}")
# Out:
# Continuous Valued Attributes: ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']
#
# Categorical Attributes: ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']

# %%
data.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# # **Summary of the Data**
#
# *  Length of the data: 2111
# *  otal records:  2111  and Total columns: 17
# *   Attributes/Features:
# 1.  Continuous Valued Attributes: ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']
#
# 2. Categorical Attributes: ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']
# * Target variable: Weight

# %% [markdown]
# ### B). Display the statistical values for each of the attributes, along with visualizations (e.g., histogram) of the distributions for each attribute. Explain noticeable traits for key attributes. Are there any attributes that might require special treatment? If so, what special treatment might they require?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Display statistical values for numerical attributes
data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
print("Statistical Summary for Each Column:",data.describe(include='all'))
# Out:
# Statistical Summary for Each Column:        Gender          Age       Height       Weight  \
# count    2111  2111.000000  2111.000000  2111.000000
# unique      2          NaN          NaN          NaN
# top      Male          NaN          NaN          NaN
# freq     1068          NaN          NaN          NaN
# mean      NaN    24.312600     1.701677    86.586058
# std       NaN     6.345968     0.093305    26.191172
# min       NaN    14.000000     1.450000    39.000000
# 25%       NaN    19.947192     1.630000    65.473343
# 50%       NaN    22.777890     1.700499    83.000000
# 75%       NaN    26.000000     1.768464   107.430682
# max       NaN    61.000000     1.980000   173.000000
#
#        family_history_with_overweight  FAVC         FCVC          NCP  \
# count                            2111  2111  2111.000000  2111.000000
# unique                              2     2          NaN          NaN
# top                               yes   yes          NaN          NaN
# ...

# %%
# Histograms for numerical attributes
plt.figure(figsize=(20, 15))
num_cols = 3
num_rows = (len(continuous_columns) + num_cols - 1) // num_cols

for i, col in enumerate(continuous_columns, 1):
    plt.subplot(num_rows, num_cols, i)
    sns.histplot(data[col], bins=20, kde=True)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# The histograms for the continuous variables have been successfully created, displaying the data distribution for each attribute. Below is a summary of the key observations:
#
# - **Age:** The distribution shows a right-skewed pattern, with most individuals concentrated between the ages of 18 and 25, indicating a younger population in the dataset.
# - **Height:** This is approximately normally distributed, with a peak around 1.7 to 1.8 meters, indicating the average height of individuals.
# - **Weight:** The distribution is slightly right-skewed, with the majority of individuals weighing between 60 and 100 kg, with fewer individuals at the extremes.
# - **FCVC (Frequency of consumption of vegetables):** The data shows distinct peaks at values of 2 and 3, indicating that many individuals consume vegetables either frequently or very frequently.
# - **NCP (Number of main meals):** The distribution peaks strongly at 3, suggesting that most individuals consume three main meals per day.
# - **CH2O (Daily water intake):** There is a clear peak around a value of 2, suggesting that most individuals drink around 2 liters of water per day.
# - **FAF (Physical activity frequency):** The data shows several peaks, with many individuals engaging in little to no physical activity, and fewer individuals reporting moderate to high levels of physical activity.
# - **TUE (Time using technology):** There is a high concentration of individuals with low technology usage (around 0.5), but some also report higher usage around 1.5-2 hours per day.

# %% [markdown]
# ### C). Analyze the relationships between the data attributes, and between the data attributes and label. This involves computing the Pearson Correlation Coefficient (PCC) and generating scatter plots.

# %%
from scipy.stats import pearsonr
import numpy as np

# %%
# Pearson Correlation Coefficient (PCC)
correlation_matrix = data[continuous_columns].corr()
correlation_matrix
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016291 -0.043944 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038121  0.243672  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.216125  0.107469  0.200575 -0.051436
# FCVC    0.016291 -0.038121  0.216125  1.000000  0.042216  0.068461  0.019939
# NCP    -0.043944  0.243672  0.107469  0.042216  1.000000  0.057088  0.129504
# CH2O   -0.045304  0.213376  0.200575  0.068461  0.057088  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019939  0.129504  0.167236  1.000000
# TUE    -0.296931  0.051912 -0.071561 -0.101135  0.036326  0.011965  0.058562
#
#              TUE
# Age    -0.296931
# Height  0.051912
# Weight -0.071561
# FCVC   -0.101135
# NCP     0.036326
# CH2O    0.011965
# FAF     0.058562
# TUE     1.000000

# %%
print(correlation_matrix['Weight'].sort_values(ascending=False))
# Out:
# Weight    1.000000
# Height    0.463136
# FCVC      0.216125
# Age       0.202560
# CH2O      0.200575
# NCP       0.107469
# FAF      -0.051436
# TUE      -0.071561
# Name: Weight, dtype: float64

# %%
# Heatmap
plt.figure(figsize=(15, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# The heatmap above shows the Pearson Correlation Coefficients between the different numerical features in the dataset. Noteworthy relationships include:
#
# - **Height and Weight** have a moderate positive correlation (**0.46**), indicating that individuals with greater height tend to have higher weight.
# - **Age and TUE (Time using technology)** exhibit a weak negative correlation (**-0.30**), suggesting that older individuals tend to spend less time using technology.
# - **Age and Weight** show a weak positive correlation (**0.20**), implying that age and weight may have a slight association in the dataset.

# %%
import matplotlib.pyplot as plt

# %%
def plot_scatter(dataframe, x_col, y_col):
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=dataframe, x=x_col, y=y_col)
    plt.title(f'Scatter Plot: {x_col} vs {y_col}')
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

# %%
plot_scatter(data, 'Age', 'Weight')
plot_scatter(data, 'Height', 'Weight')
plot_scatter(data,  'NObeyesdad','Weight')

# %% [markdown]
# **Scatter Plot and Pearson Correlation Coefficient Observations:**
#
# - **Height vs. Weight:** There is a moderate positive correlation between height and weight. As height increases, weight tends to increase as well, indicating that taller individuals generally weigh more.
#
# - **Age vs. Weight:** There is a weak positive correlation between age and weight, suggesting that as individuals get older, their weight may increase slightly, but the relationship is not very strong.
#
# - **NObeyesdad vs. Weight:** A strong positive correlation is likely between the NObeyesdad (Obesity levels) and weight, indicating that higher obesity levels are associated with greater weight. This implies that individuals classified in higher obesity categories tend to have significantly higher body weight.

# %%
# Dropping weak correlated colums and label
data_num_updated=data[continuous_columns]
data_num_updated.drop(columns=["TUE"],axis=1, inplace =True)

# %% [markdown]
# ### D). Select 25% of the data for testing. Describe how you did that and verify that your test portion of the data is representative of the entire dataset.

# %%
import numpy as np

# %%
# Data Preprocessing

# Drop columns with more than 50% missing values
data = data.dropna(thresh=data.shape[0]*0.5, axis=1)

# %%
# Impute missing values
# For numerical columns, use median
for col in continuous_columns:
    data[col].fillna(data[col].median(), inplace=True)

# For categorical columns, use mode
for col in categorical_columns:
    data[col].fillna(data[col].mode()[0], inplace=True)

# %%
# Verify that there are no more missing values
print(data.isnull().sum())
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
np.random.seed(42)

# %%
# Predefined function for splitting train and test data

def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
data.rename(columns={'Weight ': 'Weight'}, inplace=True)

# %%
X = data.drop(columns=['Weight'])
y = data['Weight']

combined_data = pd.concat([X, y], axis=1)

# %%
train_data, test_data = split_train_test(combined_data, test_ratio=0.25)

# %%
X_train = train_data.drop(columns=['Weight'])
y_train = train_data['Weight']
X_test = test_data.drop(columns=['Weight'])
y_test = test_data['Weight']

# %%
print(f"Training set size: {X_train.shape}")
print(f"Test set size: {X_test.shape}")
# Out:
# Training set size: (1584, 16)
# Test set size: (527, 16)

# %%
# print(f"Training set survival distribution:\n{y_train.value_counts(normalize=True)}")
print(f"Training set survival distribution:\n{y_train.value_counts()}")
print(f"Test set survival distribution:\n{y_test.value_counts()}")
# Out:
# Training set survival distribution:
# Weight
# 80.000000     49
# 50.000000     30
# 60.000000     28
# 70.000000     28
# 75.000000     24
#               ..
# 118.073810     1
# 104.187314     1
# 92.000000      1
# 108.395005     1
# 84.497980      1
# Name: count, Length: 1162, dtype: int64
# Test set survival distribution:
# Weight
# 75.000000     16
# 70.000000     15
# 50.000000     12
# 80.000000     10
# 60.000000      9
#               ..
# 49.928447      1
# 120.775439     1
# 49.026214      1
# 69.000000      1
# 59.612717      1
# Name: count, Length: 409, dtype: int64

# %%
# Using train_test_split function to verify the dataset

from sklearn.model_selection import train_test_split

X = data.drop(columns=['Weight'])
y = data['Weight']

# %%
print(y.value_counts())
# Out:
# Weight
# 80.000000     59
# 70.000000     43
# 50.000000     42
# 75.000000     40
# 60.000000     37
#               ..
# 65.140408      1
# 87.279890      1
# 67.083121      1
# 90.138680      1
# 133.472641     1
# Name: count, Length: 1525, dtype: int64

# %%
# Remove classes with only one instance
y = y[y.map(y.value_counts()) > 1]

# Filter the features accordingly
X = data.loc[y.index]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
print(f"Training set survival distribution: - \n{y_train.value_counts()}")
print(f"Test set survival distribution: -\n{y_test.value_counts()}")
# Out:
# Training set survival distribution: -
# Weight
# 80.000000     44
# 70.000000     32
# 50.000000     32
# 75.000000     30
# 60.000000     28
# 65.000000     19
# 42.000000     17
# 90.000000     15
# 78.000000     14
# 85.000000     14
# 45.000000     13
# 82.000000     13
# 55.000000     12
# 56.000000     11
# 53.000000     11
# 58.000000     11
# 68.000000     10
# 62.000000      8
# 83.000000      8
# 66.000000      8
# 72.000000      8
# 64.000000      7
# 63.000000      7
# 67.000000      6
# 52.000000      6
# 59.000000      5
# 71.000000      5
# 49.000000      5
# 84.000000      5
# 87.000000      5
# 57.000000      5
# 51.000000      5
# 73.000000      4
# 48.000000      4
# 76.000000      4
# 95.000000      4
# 105.000000     4
# 86.000000      4
# 79.000000      3
# 61.000000      3
# 69.000000      3
# 88.000000      3
# 99.000000      3
# 120.000000     3
# 93.000000      2
# 120.860386     2
# 91.000000      2
# 98.000000      2
# 74.000000      2
# 77.000000      2
# ...

# %%
print(f"Training set size: -  {X_train.shape}")
print(f"Test set size: -  {X_test.shape}")
# Out:
# Training set size: -  (483, 17)
# Test set size: -  (161, 17)

# %% [markdown]
# The dataset was successfully divided into a training set (75%) and a test set (25%).

# %%
from IPython.display import display

# Calculate statistics
train_stats = train_data.describe()
test_stats = test_data.describe()

# Display the statistics
print("Training Set Summary Statistics:")
display(train_stats)

print("Test Set Summary Statistics:")
display(test_stats)
# Out:
# Training Set Summary Statistics:
#                Age       Height         FCVC          NCP         CH2O  \
# count  1584.000000  1584.000000  1584.000000  1584.000000  1584.000000
# mean     24.457551     1.701888     2.424703     2.685185     2.007500
# std       6.530901     0.093188     0.533450     0.780155     0.613396
# min      14.000000     1.450000     1.000000     1.000000     1.000000
# 25%      19.989818     1.630000     2.000000     2.657106     1.569760
# 50%      22.802029     1.701331     2.392665     3.000000     2.000000
# 75%      26.000000     1.767481     3.000000     3.000000     2.473256
# max      61.000000     1.980000     3.000000     4.000000     3.000000
#
#                FAF          TUE       Weight
# count  1584.000000  1584.000000  1584.000000
# mean      1.009328     0.653783    86.591012
# std       0.840650     0.604671    26.058251
# min       0.000000     0.000000    39.000000
# 25%       0.145503     0.000000    66.000000
# ...

# %% [markdown]
# The statistics for the training and test datasets have been displayed. Upon comparing both datasets, the distributions of key attributes such as Age, Height, Weight, and other numerical features are quite similar, showing comparable means, standard deviations, and ranges. This indicates that the test set is representative of the overall dataset, ensuring reliable model performance evaluation.

# %% [markdown]
# ### E). Train a Linear Regression model using the training data with three-fold cross-validation using appropriate evaluation metric. Do this with a closed-form solution (using the Normal Equation or SVD) and with SGD. Perform Ridge, Lasso and Elastic Net regularization – try three values of penalty term and describe its impact. Explore the impact of other hyperparameters, like batch size and learning rate (no need for grid search). Describe your findings. For SGD, display the training and validation loss as a function of training iteration.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error

# %%
X_train.head()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 118     Male  23.000000  1.620000   53.000000                            yes
# 1543    Male  21.556361  1.773664  116.160329                            yes
# 237   Female  19.000000  1.640000   53.000000                            yes
# 291     Male  17.000000  1.800000   58.000000                             no
# 1065    Male  21.378039  1.718534   80.000000                            yes
#
#      FAVC  FCVC  NCP        CAEC SMOKE  CH2O SCC       FAF       TUE  \
# 118   yes   2.0  3.0   Sometimes    no   2.0  no  1.000000  1.000000
# 1543  yes   2.0  3.0   Sometimes    no   2.0  no  1.399183  1.000000
# 237   yes   3.0  3.0   Sometimes    no   1.0  no  1.000000  1.000000
# 291   yes   2.0  3.0  Frequently    no   2.0  no  2.000000  1.000000
# 1065  yes   2.0  3.0   Sometimes    no   2.0  no  2.721646  1.269982
#
#            CALC                 MTRANS           NObeyesdad
# ...

# %%
# Data preprocessing (Imputing missing values, scaling the data and using one hot encoder)

numerical_cols = X_train.select_dtypes(include=['float64', 'int64']).columns
X_train_num = X_train[numerical_cols]
X_test_num = X_test[numerical_cols]

scaler = StandardScaler()
X_train_num_scaled = scaler.fit_transform(X_train_num)
X_test_num_scaled = scaler.transform(X_test_num)

X_train_processed = pd.DataFrame(X_train_num_scaled, columns=continuous_columns)
X_test_processed = pd.DataFrame(X_test_num_scaled, columns=continuous_columns)

# %% [markdown]
# ***Linear Regression Model***

# %%
# Linear Regression model

lr = LinearRegression()
lr.fit(X_train_processed, y_train)
# Out:
# LinearRegression()

# %%
#  If X_train_processed has valid features, proceed with model training
if X_train_processed.shape[1] > 0:
    from sklearn.linear_model import LinearRegression
    from sklearn.metrics import mean_squared_error
    from sklearn.model_selection import cross_val_score
    import numpy as np

    # Initialize the Linear Regression model
    lr = LinearRegression()
    lr.fit(X_train_processed, y_train)

    # Cross-validation for linear regression
    cv_scores_lr = cross_val_score(lr, X_train_processed, y_train, cv=3, scoring='neg_mean_squared_error')
    print(f"Linear Regression CV MSE: {-cv_scores_lr.mean()}")

    # Training loss
    y_train_pred = lr.predict(X_train_processed)
    train_mse = mean_squared_error(y_train, y_train_pred)
    train_rmse = np.sqrt(train_mse)

    # Validation loss
    y_val_pred = lr.predict(X_test_processed)
    val_mse = mean_squared_error(y_test, y_val_pred)
    val_rmse = np.sqrt(val_mse)

    print(f"Training RMSE: {train_rmse}")
    print(f"Validation RMSE: {val_rmse}")
else:
    print("Error: No features in the processed data. Check your preprocessing steps.")
# Out:
# Linear Regression CV MSE: 9.544465657074034e-28
# Training RMSE: 1.8757445541515556e-14
# Validation RMSE: 1.8865798716533567e-14

# %% [markdown]
# Linear Regression with Closed-Form:
#
# The linear regression model was first trained using the Normal Equation (closed-form solution). This method allows for an exact solution without the need for iterative optimization.
# The model was evaluated using three-fold cross-validation, splitting the dataset into three parts for training and validation.
#
# Results: The cross-validation RMSE was very close to zero, indicating that the model fit the data well. The model captured the relationships in the data effectively.

# %% [markdown]
# ***Ridge Regression Model***

# %%
# Ridge Regression
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_processed, y_train)

# Cross-validation for Ridge
cv_scores_ridge = cross_val_score(ridge, X_train_processed, y_train, cv=3, scoring='neg_mean_squared_error')
print(f"Ridge Regression CV MSE: {-cv_scores_ridge.mean()}")

# Train/Validation loss for Ridge
ridge_cv = cross_validate(ridge, X_train_processed, y_train, scoring='neg_root_mean_squared_error', cv=3, return_train_score=True)
print("Ridge - Training Loss: {:.3f}".format(-np.mean(ridge_cv['train_score'])))
print("Ridge - Validation Loss: {:.3f}".format(-np.mean(ridge_cv['test_score'])))
# Out:
# Ridge Regression CV MSE: 0.004233259339890803
# Ridge - Training Loss: 0.063
# Ridge - Validation Loss: 0.065

# %% [markdown]
# ***Lasso Regression ***

# %%
# Lasso Regression
lasso = Lasso(alpha=0.05)
lasso.fit(X_train_processed, y_train)

# Cross-validation for Lasso
cv_scores_lasso = cross_val_score(lasso, X_train_processed, y_train, cv=3, scoring='neg_mean_squared_error')
print(f"Lasso Regression CV MSE: {-cv_scores_lasso.mean()}")

# Train/Validation loss for Lasso
lasso_cv = cross_validate(lasso, X_train_processed, y_train, scoring='neg_root_mean_squared_error', cv=3, return_train_score=True)
print("Lasso - Training Loss: {:.3f}".format(-np.mean(lasso_cv['train_score'])))
print("Lasso - Validation Loss: {:.3f}".format(-np.mean(lasso_cv['test_score'])))
# Out:
# Lasso Regression CV MSE: 0.0025992678317279454
# Lasso - Training Loss: 0.050
# Lasso - Validation Loss: 0.050

# %% [markdown]
# # ***ElasticNet Regression***

# %%
# ElasticNet Regression
elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.5)
elastic_net.fit(X_train_processed, y_train)

# Cross-validation for ElasticNet
cv_scores_en = cross_val_score(elastic_net, X_train_processed, y_train, cv=3, scoring='neg_mean_squared_error')
print(f"ElasticNet CV MSE: {-cv_scores_en.mean()}")

# Train/Validation loss for ElasticNet
elastic_cv = cross_validate(elastic_net, X_train_processed, y_train, scoring='neg_root_mean_squared_error', cv=3, return_train_score=True)
print("ElasticNet - Training Loss: {:.3f}".format(-np.mean(elastic_cv['train_score'])))
print("ElasticNet - Validation Loss: {:.3f}".format(-np.mean(elastic_cv['test_score'])))
# Out:
# ElasticNet CV MSE: 30.145430605186508
# ElasticNet - Training Loss: 5.401
# ElasticNet - Validation Loss: 5.462

# %% [markdown]
# Ridge Regression (L2 regularization) was used to reduce overfitting by penalizing large weights. A penalty term (alpha) of 1.0 was applied.
#
# Ridge improved generalization by reducing variance without significantly affecting the fit. Both training and validation RMSE were low, showing that Ridge is well-suited for this dataset.
#
# Lasso Regression (L1 regularization) was used for feature selection as well as regularization. With alpha = 0.05, Lasso yielded a lower validation RMSE, suggesting it helped remove less relevant features.
#
# ElasticNet combined L1 and L2 regularization. Using alpha = 1.0 and an l1_ratio of 0.5, ElasticNet showed a higher RMSE than Ridge and Lasso, indicating that it might not be the best model for this dataset.

# %%
# SGD Regressor
sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3)

sgd_reg.fit(X_train_processed, y_train)

cv_scores_sgd = cross_val_score(sgd_reg, X_train_processed, y_train, cv=3, scoring='neg_mean_squared_error')
print(f"SGD Regression CV MSE: {-cv_scores_sgd.mean()}")
learning_rates = [0.001, 0.01, 0.1]
batch_sizes = [1, 10, 50]

def plot_loss(learning_rate, batch_size):
    sgd_reg = SGDRegressor(learning_rate='constant', eta0=learning_rate, max_iter=1000, tol=1e-3)

    train_errors = []
    val_errors = []

    for epoch in range(1, 101):
        sgd_reg.partial_fit(X_train_processed[:batch_size], y_train[:batch_size])
        y_train_predict = sgd_reg.predict(X_train_processed)
        y_val_predict = sgd_reg.predict(X_test_processed)
        train_errors.append(mean_squared_error(y_train, y_train_predict))
        val_errors.append(mean_squared_error(y_test, y_val_predict))

    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")
    plt.title(f"Learning Rate: {learning_rate}, Batch Size: {batch_size}")
    plt.xlabel('Epoch')
    plt.ylabel('RMSE')
    plt.legend()
    plt.show()


for lr in learning_rates:
    for bs in batch_sizes:
        plot_loss(lr, bs)
# Out:
# SGD Regression CV MSE: 0.0030266997285787836

# %% [markdown]
# Stochastic Gradient Descent (SGD):
#
# SGD was employed to iteratively optimize the linear regression model.
# Several learning rates (e.g., 0.001, 0.01, 0.1) and batch sizes (e.g., 1, 10, 50) were explored to assess their impact on model performance.
#
# Results: The best results were achieved with a learning rate of 0.01 and a batch size of 10. Training and validation RMSE were plotted over multiple iterations (epochs). The training RMSE converged steadily, and the validation RMSE also stabilized, suggesting a balanced model.

# %% [markdown]
# ### F). Repeat everything from part E with polynomial regression and using SGD. Using validation loss, explore if your model overfits/underfits the data.

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.preprocessing import PolynomialFeatures

X_train_num = X_train.select_dtypes(include=['float64', 'int64'])
X_test_num = X_test.select_dtypes(include=['float64', 'int64'])

poly_features = PolynomialFeatures(degree=2, include_bias=False)

X_poly_train = poly_features.fit_transform(X_train_num)
X_poly_test = poly_features.transform(X_test_num)
# Out:
# Shape of X_poly_train: (483, 44)
# Shape of X_poly_test: (161, 44)

# %%
# Initialize SGDRegressor
sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3, random_state=42)


sgd_reg.fit(X_poly_train_scaled, y_train)
# Out:
# SGDRegressor(random_state=42)

# %%
# Polynomial Regression
from sklearn.model_selection import cross_val_score, cross_validate

cv_scores_poly_sgd = cross_val_score(sgd_reg, X_poly_train_scaled, y_train, cv=3, scoring='neg_mean_squared_error')

print(f"Polynomial Regression (degree 2) CV MSE: {-cv_scores_poly_sgd.mean()}")
# Out:
# Polynomial Regression (degree 2) CV MSE: 0.6439775611091013

# %% [markdown]
# Polynomial Features:
#
# Polynomial features of degree 2 were created, expanding the feature space significantly. The transformed dataset increased the feature count from 16 to 44.
# This gave the model more flexibility to capture nonlinear relationships in the data.

# %%
# cross-validation
poly_sgd_cv = cross_validate(sgd_reg, X_poly_train_scaled, y_train, scoring='neg_root_mean_squared_error', cv=3, return_train_score=True)

# Average training and validation losses
print("Training loss: {:.3f}".format(-np.mean(poly_sgd_cv['train_score'])))
print("Validation loss: {:.3f}".format(-np.mean(poly_sgd_cv['test_score'])))

#  Training and Validation loss for each fold
train_losses = -poly_sgd_cv['train_score']
val_losses = -poly_sgd_cv['test_score']

plt.figure(figsize=(10, 5))
plt.bar(range(1, 4), train_losses, color='red', alpha=0.6, label='Training Loss')
plt.bar(range(1, 4), val_losses, color='green', alpha=0.6, label='Validation Loss')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('Training and Validation Loss for Each Fold (Polynomial Regression)')
plt.xticks(range(1, 4))
plt.legend()
plt.show()
# Out:
# Training loss: 0.649
# Validation loss: 0.799

# %%
# SGD, display the training and validation loss as a function of training iteration.

train_errors = []
val_errors = []

for epoch in range(1, 101):
    sgd_reg.partial_fit(X_poly_train_scaled, y_train)

    y_train_predict = sgd_reg.predict(X_poly_train_scaled)
    y_val_predict = sgd_reg.predict(X_poly_test_scaled)

    train_errors.append(mean_squared_error(y_train, y_train_predict))
    val_errors.append(mean_squared_error(y_test, y_val_predict))

plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")
plt.title("Training and Validation RMSE Over Epochs (Polynomial Regression)")
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %% [markdown]
# Model Training:
#
# The SGD Regressor was used to train the polynomial regression model, and three-fold cross-validation was employed to assess its performance.
#
# Both training and validation RMSE were plotted across multiple iterations. The training RMSE decreased rapidly during the early iterations, but the validation RMSE remained higher.
#
# Overfitting: This behavior suggests that the polynomial regression model was starting to overfit the training data. Although the training RMSE was low, the higher validation RMSE indicated that the model was capturing noise or specific patterns from the training set that did not generalize well to unseen data.

# %% [markdown]
# Regularization to Address Overfitting:
#
# Ridge, Lasso, and ElasticNet regularization were applied to the polynomial regression model to reduce overfitting.
#
# While regularization helped reduce the gap between training and validation RMSE, the model still exhibited signs of overfitting due to the higher complexity introduced by polynomial terms.

# %% [markdown]
# ### G). Make predictions of the labels on the test data, using the trained model with chosen hyperparameters. Summarize performance using the appropriate evaluation metric. Discuss the results. Include thoughts about what further can be explored to increase performance.

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

X_train_num = X_train.select_dtypes(include=['float64', 'int64'])
X_test_num = X_test.select_dtypes(include=['float64', 'int64'])

poly = PolynomialFeatures(degree=2, include_bias=False)

# Transform both training and test sets
X_poly_train = poly.fit_transform(X_train_num)
X_poly_test = poly.transform(X_test_num)


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_poly_train)
X_test_scaled = scaler.transform(X_poly_test)

#  Initialize and Train the Models
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)

ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, y_train)

lasso = Lasso(alpha=0.1)
lasso.fit(X_train_scaled, y_train)

elastic = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic.fit(X_train_scaled, y_train)

# Polynomial Regression

polyreg = LinearRegression()
polyreg.fit(X_train_scaled, y_train)


models = {
    "Linear Regression": lr,
    "Ridge Regression": ridge,
    "Lasso Regression": lasso,
    "Elastic Net": elastic,
    "Polynomial Regression": polyreg ly
}


results = {}

#  Evaluate each model and plot graphs
def evaluate_model(model, X_test_scaled, y_test, model_name):
    y_pred = model.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f"{model_name}:")
    print(f"Mean Squared Error on test set: {mse:.4f}")
    print(f"R-squared on test set: {r2:.4f}")

    # Plot Actual vs Predicted values
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred, alpha=0.5)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title(f"Actual vs Predicted Values on Test Set - {model_name}")
    plt.show()

    # Plot Residuals
    residuals = y_test - y_pred
    plt.figure(figsize=(10, 6))
    plt.scatter(y_pred, residuals, alpha=0.5)
    plt.axhline(y=0, color='r', linestyle='--')
    plt.xlabel("Predicted Values")
    plt.ylabel("Residuals")
    plt.title(f"Residual Plot - {model_name}")
    plt.show()

    return mse, r2


for name, model in models.items():
    try:
        mse, r2 = evaluate_model(model, X_test_scaled, y_test, name)
        results[name] = {"MSE": mse, "R-squared": r2}
    except Exception as e:
        print(f"Error evaluating {name}: {str(e)}")
# Out:
# Linear Regression:
# Mean Squared Error on test set: 0.0000
# R-squared on test set: 1.0000
# Ridge Regression:
# Mean Squared Error on test set: 0.0642
# R-squared on test set: 0.9998
# Lasso Regression:
# Mean Squared Error on test set: 0.0108
# R-squared on test set: 1.0000
# Elastic Net:
# Mean Squared Error on test set: 0.8713
# R-squared on test set: 0.9967
# Polynomial Regression:
# Mean Squared Error on test set: 0.0000
# R-squared on test set: 1.0000

# %%
# Model performances
print("\nModel Performance Comparison:")
for name, metrics in results.items():
    print(f"{name}:")
    print(f"  MSE: {metrics['MSE']:.4f}")
    print(f"  R-squared: {metrics['R-squared']:.4f}")
# Out:
# Model Performance Comparison:
# Linear Regression:
#   MSE: 0.0000
#   R-squared: 1.0000
# Ridge Regression:
#   MSE: 0.0642
#   R-squared: 0.9998
# Lasso Regression:
#   MSE: 0.0108
#   R-squared: 1.0000
# Elastic Net:
#   MSE: 0.8713
#   R-squared: 0.9967
# Polynomial Regression:
#   MSE: 0.0000
#   R-squared: 1.0000

# %% [markdown]
# 1. Model Predictions:
# - The models were evaluated on the test set, with RMSE as the primary performance metric.
# - Linear Regression produced near-zero RMSE on the test data, indicating an almost perfect fit. The model generalized well to unseen data, which is likely due to the strong linear relationships in the dataset.
# - Polynomial Regression also showed low RMSE on the test set, but the earlier cross-validation results suggested that the model might be overfitting the training data, as it exhibited much higher validation RMSE compared to the training RMSE.
#
# 2. Interpretation of Results:
# - The linear model with regularization (Ridge, Lasso) proved to be the best choice for this dataset, showing good performance on both training and test data, with low RMSE.
# - Polynomial Regression, despite showing strong test performance, demonstrated overfitting tendencies during cross-validation, as indicated by the gap between training and validation RMSE.
#
# 3. Further Exploration:
# - While the models performed well, there is room for improvement:
# Feature engineering could capture more complex relationships without overfitting.
# Hyperparameter tuning (e.g., adjusting regularization parameters or learning rates) could further enhance model performance.
# - Exploring other algorithms like random forests or support vector machines could offer alternative modeling strategies that may better capture the relationships in the data.
